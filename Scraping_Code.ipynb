# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import pandas as pd
import time
 
options = Options()
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
# options.add_argument("--headless=new")
options.add_argument("--window-size=1920,1080")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
 
jobs_list = []
positions = ['Data Engineer', 'Data Scientist','AI Developer', 'Machine Learning Engineer']
driver = webdriver.Chrome(options=options)
driver.get('https://wuzzuf.net/jobs/egypt')
driver.maximize_window()

for position in positions:
    
    driver.find_element(By.NAME,'q').send_keys(position)
    driver.find_element(By.XPATH,'//button[@type=\'submit\']').click()
                
    time.sleep(3)
    driver.refresh()
  
      
    time.sleep(5)
    try:
        for page in range(3):
                jobs = driver.find_elements(By.CLASS_NAME, 'css-pkv5jc')
            
                for job in jobs:
                            
                            jobName = job.find_element(By.CLASS_NAME,'css-s5fwzh').text
                            jobCompany = job.find_element(By.CLASS_NAME, 'css-ipsyv7').text
                            jobLocation = job.find_element(By.CLASS_NAME,'css-16x61xq').text
                            jobType = job.find_element(By.CLASS_NAME,'css-a85cz4').text
                            jobSite = job.find_element(By.XPATH,'//div[@class=\'css-9i2afk\']//div[1]//div[1]//div[2]//div[1]//a[2]//span[1]').text
                            jobExp = job.find_element(By.CSS_SELECTOR,' div:nth-child(1) > div:nth-child(3) > div:nth-child(2) > span:nth-child(2)').text
                            jobURL = job.find_element(By.CLASS_NAME,'css-o171kl').get_attribute('href')

                            jobs_list.append(
                            {
                                    'Job_Title':jobName,
                                    'Company':jobCompany,
                                    'Location':jobLocation,
                                    'Type':jobType,
                                    'Work_Mode':jobSite,
                                    'Req_Experience':jobExp,
                                    'URL':jobURL
                            })
                            

                driver.find_element(By.XPATH,'//a[@aria-label=\'Next page\']//i[@class=\'css-b80bsd efou2fk0\']//*[name()=\'svg\']').click()
                time.sleep(5)
    except:
        continue            

driver.close()

# %%
df = pd.DataFrame(jobs_list)
df.to_csv('wuzzuf_jobs.csv', index=False)
df
# Out:
#                                             Job_Title  \
# 0   Associate System Engineer “Associate Data Mana...
# 1                                Senior Data Engineer
# 2   Data Center Facility Electrical/ Mechanical En...
# 3         Data Engineer (Infrastructure & Operations)
# 4                           Sr. Data Engineer - Spark
# ..                                                ...
# 78                            Generative AI Engineer.
# 79                              Senior Data Scientist
# 80                                        AI Engineer
# 81                   Embedded Systems & AI Instructor
# 82                  Academic & IT Curriculum Director
#
#                            Company                  Location       Type  \
# 0      Target Integrated Systems -              Cairo, Egypt  Full Time
# 1            Vertex Technologies -              Cairo, Egypt  Full Time
# 2                      GPX Egypt -   New Cairo, Cairo, Egypt  Full Time
# 3   MEAHCO - Saudi German Health -    Katameya, Cairo, Egypt  Full Time
# 4                         Techsa -              Cairo, Egypt  Full Time
# ..                             ...                       ...        ...
# 78                Etisalat Egypt -  Mohandessin, Giza, Egypt  Full Time
# 79           Vertex Technologies -              Cairo, Egypt  Full Time
# 80                       ITGoals -   New Cairo, Cairo, Egypt  Full Time
# 81                          MICA -        Haram, Giza, Egypt  Full Time
# 82                          MICA -        Haram, Giza, Egypt  Full Time
#
#    Work_Mode       Req_Experience  \
# 0    On-site   · 0 - 3 Yrs of Exp
# 1    On-site      · 5+ Yrs of Exp
# 2    On-site   · 3 - 5 Yrs of Exp
# 3    On-site   · 5 - 8 Yrs of Exp
# 4    On-site      · 7+ Yrs of Exp
# ..       ...                  ...
# 78    Remote   · 3 - 7 Yrs of Exp
# 79    Remote      · 5+ Yrs of Exp
# 80    Remote   · 3 - 7 Yrs of Exp
# 81    Remote   · 0 - 2 Yrs of Exp
# 82    Remote  · 8 - 20 Yrs of Exp
#
#                                                   URL
# 0   https://wuzzuf.net/jobs/p/ubsrja3n94m1-associa...
# 1   https://wuzzuf.net/jobs/p/3x6prdwpt2tz-senior-...
# 2   https://wuzzuf.net/jobs/p/39xm37penfcr-data-ce...
# 3   https://wuzzuf.net/jobs/p/mhqqwhx31ryd-data-en...
# 4   https://wuzzuf.net/jobs/p/4w6f7tucldaf-sr-data...
# ..                                                ...
# 78  https://wuzzuf.net/jobs/p/gjkeoggram76-generat...
# 79  https://wuzzuf.net/jobs/p/yzal3d0v861d-senior-...
# 80  https://wuzzuf.net/jobs/p/obuc0novnoqj-ai-engi...
# 81  https://wuzzuf.net/jobs/p/zpbuc7jbk256-embedde...
# 82  https://wuzzuf.net/jobs/p/vtco6sgxfjd7-academi...
#
# [83 rows x 7 columns]
